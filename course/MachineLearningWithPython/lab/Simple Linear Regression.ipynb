# %%
import pandas as pd
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !wget -O FuelConsumption.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Out:
# --2019-02-03 21:24:53--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/FuelConsumptionCo2.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.193
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72629 (71K) [text/csv]
# Saving to: ‘FuelConsumption.csv’
#
# FuelConsumption.csv 100%[===================>]  70.93K   120KB/s    in 0.6s
#
# 2019-02-03 21:25:05 (120 KB/s) - ‘FuelConsumption.csv’ saved [72629/72629]

# %%
df = pd.read_csv('FuelConsumption.csv')
fig=(20,8)
cdf = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]

# %%
cdf.hist(figsize=(20,8))
plt.show()

# %%
plt.scatter(cdf.FUELCONSUMPTION_COMB,cdf.CO2EMISSIONS)
plt.xlabel('FUELCONSUMPTION COMB')
plt.ylabel('CO@ EMISSION')
plt.show()

# %%
plt.scatter(cdf.CO2EMISSIONS,cdf.CYLINDERS)
plt.xlabel('CO2 Emission')
plt.ylabel('Cylinders')
plt.show()

# %%
plt.scatter(cdf.CO2EMISSIONS,cdf.ENGINESIZE)
plt.xlabel('CO2 Emission')
plt.ylabel('Engine')
plt.show()

# %%
lists = list(range(1,2000000))
newlists= np.random.rand(len(lists))<.02
len(newlists)
# Out:
# 1999999

# %%
newlists
# Out:
# array([0.09023855, 0.44653927, 0.05571349, ..., 0.63489787, 0.39563563,
#        0.72874203])
